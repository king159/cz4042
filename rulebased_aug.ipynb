# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import random
from typing import Dict
from collections import defaultdict
import pandas as pd
import nltk
from bs4 import BeautifulSoup
import re
from nltk.tokenize.toktok import ToktokTokenizer
nltk.download('stopwords')
nltk.download('punkt')

SEED = 1946614
random.seed(SEED)

def clean_dataset(old_pd:pd.DataFrame) -> pd.DataFrame:
    data = old_pd
    lowercase_review = [i.lower() for i in data['review'].tolist()]
    data['cleaned'] = lowercase_review
    print(data['cleaned'])
    tokenizer=ToktokTokenizer()
    stopword_list = nltk.corpus.stopwords.words('english')
    def _remove_stopwords(text):
        tokens = tokenizer.tokenize(text)
        tokens = [token.strip() for token in tokens]
        final_tokens = [token for token in tokens if token not in stopword_list]
        cleaned_text = ' '.join(final_tokens)    
        return cleaned_text
    data['cleaned'] = data['cleaned'].apply(_remove_stopwords)
    def _remove_html(text):
        soup = BeautifulSoup(text, "html.parser")
        return soup.get_text()
    data['cleaned'] = data['cleaned'].apply(_remove_html)
    def _remove_brackets(text):
        return re.sub('\[[^]]*\]', '', text)
    data['cleaned'] = data['cleaned'].apply(_remove_brackets)
    data['label'] = data['sentiment'].astype('category').cat.codes
    return data

def prepare_dataset(df:pd.DataFrame, mode='full') -> Dict[str,list]:
    data = [(r, label) for r, label in zip(df['cleaned'], df['label'])]
    random.shuffle(data)
    datasize = len(df)
    data2 = dict.fromkeys(['train', 'val', 'test'])
    if mode == 'full':
        # 35000 train, 7500 dev test
        data2['train'], data2['val'], data2['test']  = data[0:int(0.7*datasize)], data[int(0.7*datasize):int(0.85*datasize)], data[int(0.85*datasize):]
    elif mode == 'small':
        # 3500 train, 7500 dev test
        data2['train'], data2['val'], data2['test']  = random.choices(data[0:int(0.7*datasize)], k=int(0.7*datasize/5)), data[int(0.7*datasize):int(0.85*datasize)], data[int(0.85*datasize):]
    outputs = defaultdict()
    for x in ['train', 'val', 'test']:
        outputs['%s_sentences'%x] = [d[0] for d in data2[x]]
        outputs['%s_labels'%x] = [d[1] for d in data2[x]]
    return outputs

# %%
data = pd.read_csv('/content/drive/MyDrive/Y3S1/CZ4042 Neural network and deep learning/Group project /data/IMDB Dataset.csv')

# %%
cleaned_data = clean_dataset(data)
# cleaned_data = prepare_dataset(cleaned_data,mode='small')

# %%
# !pip install nlpaug
import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas
import nlpaug.flow as naf

from nlpaug.util import Action

# %%
original_output = prepare_dataset(cleaned_data)
train_sentences_full = original_output['train_sentences']
train_labels_full = original_output['train_labels']
val_sentences_full = np.array(original_output['val_sentences'])
val_labels_full = np.array(original_output['val_labels'])
test_sentences_full = np.array(original_output['test_sentences'])
test_labels_full = np.array(original_output['test_labels'])

# %% [markdown]
# ## Character augmentation

# %% [markdown]
# #### Check augmenter

# %% [markdown]
# OCR

# %%
text = train_sentences[0]
aug_ocr = nac.OcrAug()
augmented_texts = aug_ocr.augment(text, n=5)
print("Original:")
print(text)
print("Augmented Texts:")
print(augmented_texts)
# Out:
# Original:
# level high expectation sit watch comedy cast headed cary grant , jayne mansfield , ray walston werner klemperer. expectations buoyed film directed stanley donen , whose comic touch evident , among others , damn yankees ! , bedazzled charade. first five minutes , , seems expectations might met . nothing. supposed light comedy , plunges leaden , heavy handed melodrama , nary chuckle had.relative newcomer suzy parker often criticized performance , lack one , film , movie even great cary grant frequently appears flat wooden , attacking parker seems unfair. even bright light audrey hepburn doris day could changed fortunes meandering , dreary wholly pointless script , drags lamely along drags viewer ' interest patience it.the rest cast , especially ray walston , keep trying breath life proceedings , horrible script beyond resuscitation. desperate , inane effort drag half hearted laugh numbed audience film ' final moments serves add insult injury.this film nothing major disappointment levels .
# Augmented Texts:
# ["level high expectation sit watch comedy cast headed cary grant, jayne mansfield, ray walston werner klemperer. expectations buoyed film directed stanley donen, whose comic touch evident, among others, damn yankees! , bedazzled charade. first five minutes, , seems expectations might met. nothing. 8uppo8ed light comedy, plunges 1eaden, heavy handed melodrama, nary chuckle had. relative newcomer suzy parker often criticized performance, lack one, fi1m, movie even great cary grant frequently appears f1at wooden, attacking parker seems unfair. even bright light audrey hepburn duri8 day could changed fortunes meandering, dreary wholly pointless script, drags 1ame1y along drags viewer ' interest patience it. the rest cast, especially ray walston, keep trying breath life proceedings, horrible script beyond resuscitation. desperate, inane effort dka9 half hearted laugh numbed audience film ' final moments serves add insult injury. this film nothing majuk disappointment levels.", "level high expectation sit watch c0medy cast headed cary grant, jayne mansfield, ray walston werner klemperer. expectations buoyed fi1m directed stanley donen, whose comic touch evident, among others, damn yankees! , bedazzled charade. fik8t five minutes, , seems expectations might met. nothing. supposed light comedy, plunges leaden, heavy handed melodrama, nary chuckle had. relative newcomer suzy parker often criticized performance, lack one, film, movie even great cary grant frequently appears flat wooden, attacking parker seems unfair. even bright light audrey hepburn doris day could changed fortunes meandekin9, dreary wholly pointless script, drags lamely along drags viewer ' interest patience it. the rest cast, especially ray wal8t0n, keep trying breath life proceedings, horrible script beyond resuscitation. desperate, inane effort drag half hearted laugh numbed audience film ' final m0ment8 serves add insult injury. this fi1m nothing major disappointment levels.", "level high expectation sit watch comedy cast headed cary grant, jayne mansfield, ray walston werner klemperer. expectations buoyed film directed stanley donen, whose comic touch evident, among others, damn yanree8! , bedazzled charade. first five minutes, , 8eem8 expectations might met. nothing. supposed light comedy, plunges leaden, heavy handed melodrama, nary chuckle had. relative newcomer suzy parker often criticized performance, lack one, film, movie even great cary grant frequently appears flat wooden, attacking parker seems unfair. even bright light audrey hepburn doris day could changed fortunes meandering, dreary wholly pointless script, drags lamely along drags viewer ' interest patience it. the ke8t cast, especially ray walston, keep trying breath life proceedings, h0rri6le script beyond resuscitation. desperate, inane effort drag half hearted lao9h numbed audience film ' final moments serves add insult injury. this film nothing major disappointment levels.", "level high expectation 8it watch comedy cast headed cary grant, jayne mansfield, ray walston weknek klemperer. expectati0n8 buoyed film directed stanley donen, whose comic touch evident, among others, damn yankees! , bedazzled charade. first five minutes, , seems expectations might met. nothing. supposed light comedy, plunges leaden, heavy handed melodrama, nary chuckle had. relative newcomer suzy parker often criticized performance, lack one, film, movie even great cary grant frequently appears flat wu0den, attacking parrek seems unfair. even bright light audrey hepburn doris day c0u1d changed fortunes meandering, dreary wholly pointless script, dkag8 lamely along drags viewer ' interest patience it. the rest cast, especially ray walston, keep trying breath life proceedings, horrible script beyond resuscitation. desperate, inane effort drag half hearted laugh numbed audience film ' final moments serves add insult injury. this film nothing major disappointment levels.", "level high expectation sit watch comedy cast headed ca ...

# %% [markdown]
# Keyboard augmenter

# %%
aug_key = nac.KeyboardAug()
augmented_text = aug_key.augment(text)
print("Original:")
print(text) 
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# level high expectation sit watch comedy cast headed cary grant , jayne mansfield , ray walston werner klemperer. expectations buoyed film directed stanley donen , whose comic touch evident , among others , damn yankees ! , bedazzled charade. first five minutes , , seems expectations might met . nothing. supposed light comedy , plunges leaden , heavy handed melodrama , nary chuckle had.relative newcomer suzy parker often criticized performance , lack one , film , movie even great cary grant frequently appears flat wooden , attacking parker seems unfair. even bright light audrey hepburn doris day could changed fortunes meandering , dreary wholly pointless script , drags lamely along drags viewer ' interest patience it.the rest cast , especially ray walston , keep trying breath life proceedings , horrible script beyond resuscitation. desperate , inane effort drag half hearted laugh numbed audience film ' final moments serves add insult injury.this film nothing major disappointment levels .
# Augmented Text:
# level high expectation sit watch comedy cast headed cary grant, jayne mansfield, ray walston werner klemperer. expectations buoyed film dofected stanley donen, whose comic touch evident, among others, wamn yankees! , bedazzled charade. first five minutes, , sdems expectations might met. nothing. supposed light comedy, plunges leaden, heavy handed melodrama, nary chuckle had. relative newcomer suzy parker often criticized performance, lack one, film, mov(e even great cary grant fDeWuFntly apprarx flat wooden, attacking parker seems unfair. even bright light audrey hepburn doris day coild changed fortunes meandering, dreary wholly pointless script, drags lamely along drags giewer ' interest patience it. the rest cast, especially ray walston, keep trying breath lif@ proceedings, horrible script beyond resuscitation. desperate, inane effort drag half hearted laugh numbed audience fi/m ' final moments serves add insult injury. this film nothing major disappointment levels.

# %% [markdown]
# Random character augmenter

# %% [markdown]
# Insertion

# %%
aug_rand_ins = nac.RandomCharAug(action="insert")
augmented_text = aug_rand_ins.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# level high expectation sit watch comedy cast headed cary grant , jayne mansfield , ray walston werner klemperer. expectations buoyed film directed stanley donen , whose comic touch evident , among others , damn yankees ! , bedazzled charade. first five minutes , , seems expectations might met . nothing. supposed light comedy , plunges leaden , heavy handed melodrama , nary chuckle had.relative newcomer suzy parker often criticized performance , lack one , film , movie even great cary grant frequently appears flat wooden , attacking parker seems unfair. even bright light audrey hepburn doris day could changed fortunes meandering , dreary wholly pointless script , drags lamely along drags viewer ' interest patience it.the rest cast , especially ray walston , keep trying breath life proceedings , horrible script beyond resuscitation. desperate , inane effort drag half hearted laugh numbed audience film ' final moments serves add insult injury.this film nothing major disappointment levels .
# Augmented Text:
# level hignh expectation sit watch comedy cast headed cary grant, jayne mansfield, ray walston werner klemperer. expectations buoyed film directed stanley donen, whose comic touch evident, amBong others, damn yankees! , bedazzled charade. first five minutes, , seems expectations might met. nothing. supposed lig&ht comedy, plunges leaden, heavy handed melodrama, nary chuckle had. relative newcomer suzy parker oEften criticized performance, lack one, film, movie even great cary grant frequently appears flat woodezn, attacking parker seems unfair. even bright light audrey hepburn doris day could changed fortunes meandering, drearvy wholly pointless Uscript, drags lamely along drags viewer ' interest patience it. the rest cast, especially ray walston, keep trying breath life proceedings, horrible script beyond res*us6citati!on. desperate, inane effort drag half hearted laugh numbed audience film ' final moments sernves add insult inj7ury. this film nothing major disappointment levels.

# %% [markdown]
# Substitute

# %%
aug_rand_sub = nac.RandomCharAug(action="substitute")
augmented_text = aug_rand_sub.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# level high expectation sit watch comedy cast headed cary grant , jayne mansfield , ray walston werner klemperer. expectations buoyed film directed stanley donen , whose comic touch evident , among others , damn yankees ! , bedazzled charade. first five minutes , , seems expectations might met . nothing. supposed light comedy , plunges leaden , heavy handed melodrama , nary chuckle had.relative newcomer suzy parker often criticized performance , lack one , film , movie even great cary grant frequently appears flat wooden , attacking parker seems unfair. even bright light audrey hepburn doris day could changed fortunes meandering , dreary wholly pointless script , drags lamely along drags viewer ' interest patience it.the rest cast , especially ray walston , keep trying breath life proceedings , horrible script beyond resuscitation. desperate , inane effort drag half hearted laugh numbed audience film ' final moments serves add insult injury.this film nothing major disappointment levels .
# Augmented Text:
# level high expectation sit watch comedy cast headed cary grant, jacne mansfield, ray walston werner klemperer. expectations buoyed film directed stanley donen, whose comic touch evident, among others, damn yankees! , bedazzled ch^radz. first five minutes, , seems expectations mig4t met. nothing. supposed light comedy, plunges leaden, heavy handed melodrama, nary chuckle had. relative newcomer suzy parker often criticized performance, lcck one, film, movie even great cary grant frequently appears flat wooden, attacking parker seems unfair. even bright light audrey hepburn doris day could changed fortunes meandering, dreary wholly pointless script, doags lamely along drags viewer ' interest patience it. the rest cast, especially ray walston, keep trying bZeath life proceedings, horrible script beyond resuscitation. desperate, inane effort drag half hearted laZgh numbeT audience fiFm ' final moments serves add insult injury. this fil# nothing major disappointment levels.

# %% [markdown]
# Swap character randomly

# %%
aug_rand_swap = nac.RandomCharAug(action="swap")
augmented_text = aug_rand_swap.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# level high expectation sit watch comedy cast headed cary grant , jayne mansfield , ray walston werner klemperer. expectations buoyed film directed stanley donen , whose comic touch evident , among others , damn yankees ! , bedazzled charade. first five minutes , , seems expectations might met . nothing. supposed light comedy , plunges leaden , heavy handed melodrama , nary chuckle had.relative newcomer suzy parker often criticized performance , lack one , film , movie even great cary grant frequently appears flat wooden , attacking parker seems unfair. even bright light audrey hepburn doris day could changed fortunes meandering , dreary wholly pointless script , drags lamely along drags viewer ' interest patience it.the rest cast , especially ray walston , keep trying breath life proceedings , horrible script beyond resuscitation. desperate , inane effort drag half hearted laugh numbed audience film ' final moments serves add insult injury.this film nothing major disappointment levels .
# Augmented Text:
# level high expectation sit watch comedy cast headed cary grant, jayne mansfield, ray walston werner klemperer. expectations buoyed film directed stanley donen, whose comic touch evident, among others, admn yankees! , bedazzled charade. first five minutes, , seems expectations mgiht met. nothing. supposed light ocmedy, plunges leaden, heavy handed melodrama, nary hccukle had. relative newcomer suzy parker often criticized performance, lack one, film, omvie even great cary grant frequently appears flat wooden, attacking parker seems unfair. even bright light audrey hepburn doris day could changed fortunes meandering, dreary wholly pointless script, drags lamely along dargs viewer ' interest patience it. the rest cast, especially ray walston, keep trying rbeath life proceedings, horrible script beyond resuscitation. desperate, inane effort drag half hearted laugh numbed audience flim ' final moments serevs add insult injury. this film nothing major disappointment levels.

# %% [markdown]
# Delete character randomly

# %%
aug_rand_del = nac.RandomCharAug(action="delete")
augmented_text = aug_rand_del.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# level high expectation sit watch comedy cast headed cary grant , jayne mansfield , ray walston werner klemperer. expectations buoyed film directed stanley donen , whose comic touch evident , among others , damn yankees ! , bedazzled charade. first five minutes , , seems expectations might met . nothing. supposed light comedy , plunges leaden , heavy handed melodrama , nary chuckle had.relative newcomer suzy parker often criticized performance , lack one , film , movie even great cary grant frequently appears flat wooden , attacking parker seems unfair. even bright light audrey hepburn doris day could changed fortunes meandering , dreary wholly pointless script , drags lamely along drags viewer ' interest patience it.the rest cast , especially ray walston , keep trying breath life proceedings , horrible script beyond resuscitation. desperate , inane effort drag half hearted laugh numbed audience film ' final moments serves add insult injury.this film nothing major disappointment levels .
# Augmented Text:
# level high expectation sit watch comedy cast headed cary grant, jayne manseld, ray walston werner klemperer. expectations buoye film directed stanley donen, whose comic touch evident, among others, damn yankees! , bedazzled charade. first five minutes, , seems expecaios might met. nothing. supposed light comedy, plunges leaden, heavy handed melodrama, nary chuckle had. relative newcomer suzy parker ofte crtczed performance, lack one, film, movie even great cary grant frequently appears flat wooden, attacking parker seems unfair. even bright light audrey hepburn doris day could changed fortunes meandering, dreary wholly pointless script, drags lamely along drgs viewer ' interest patience it. the rest cast, especially ray walston, kep trying breath lif roceedis, horrible script beyond resuscitation. desperate, inane effort drag half hearted laugh numbed adince film ' final moments serves add insult injury. this film nothing major disappointment levels.

# %% [markdown]
# #### Augment all data

# %%
aug = naf.Sometimes([
    aug_ocr,
    aug_key,
    aug_rand_ins,
    aug_rand_sub,
    aug_rand_del,
    aug_rand_swap,
])

augmented_text = aug.augment(text, n=5)
augmented_text
# Out:
# ["level high expectation sit watch comedy cast headed cary grant, jayne mansfield, ray walston werner klemperer. expectations buoyed film directed stanley donen, whose comic touch vidnt, among others, damn yankees! , bedazzled charade. first five minutes, , seems expectations might met. nothing. supposed light comedy, plunges leaden, heavy handed melodrama, nary chuckle had. relative newcomer suzy parker often criticized performance, lack one, film, movie even great cary grant frequently appears flat wooden, attacking parker seems unfair. eve bright light audrey hepburn doris day could changed fortunes meandering, dreary wholl pointless scipt, drags lamely along drags viewer ' interest patience it. the res cast, especially ray walston, keep trying breath life ocedings, horrible script beyond esusciatin. desperate, inane effort drag half hearted lagh numbed audience film ' final moments serves add insult injury. tis flm nothing major disappointment levels.",
#  "level high expectation sit watch comdy cast headed cary grant, jayne mansfield, ray walston werner klemperer. expectations buoyed film directed stanley donen, whose comic touch evident, among others, damn yankees! , bedazzled charade. first five minutes, , seems exptation might met. nothing. supposed light comedy, plunges leaden, heavy hnded melodrama, nary chuckle had. relative newcomer suzy parker often criticized performance, lack one, film, movie even great car grant frequently appears flat wooden, atackig parker seems unfair. even bright light audrey hepburn doris day could changed fortunes meandering, dreary wholly pointless script, drags lamel along drags vieer ' interest patience it. the rest cast, especially ray walston, keep trying breath life proceedings, orrile scipt beyond resuscitation. desperate, inane effort drag half hearted laugh numbed audience film ' final moments serves add insult injury. this film notig major disappointment levels.",
#  "1eve1 high expectation sit watch comedy cast headed cary greant, jayne man8fie1d, ray walston werner klempserNer. expectations buoyed film directed stanley donen, whose comic touch evident, among others, damn yankees! , bedazzled chakade. f#irst f (ve minutes, , seems expectations mjght met. nothing. sHppKsed light comedy, plunges leaden, heavy handed melodrama, nary chuckle had. relative newcomer sutzy parker often ckitici2ed performance, lAck one, film, movie eveHn great cary grant frequently appears f1a0t wooden, attacking parker seems unfair. even briRht light audre & hep6orn doris day could changed fortunes meandering, dreary whol, y pointless script, dka9s lamely Ralong drags viewer ' interest Dpatkience it. the rest cast, especially ray walston, keep trying breath life pr (cRedingZ, h0rri6le script beyond resueSitatiLn. desperate, inane effort drag half hearted Kaugh numbed audience film ' final mo0mentBs serves add insulDt injury. this film nothing major disappointment leve18.",
#  "level high expectation sit wath comedy cast headed ary grant, jayne KmansfieSld, ray walsftoIn werner klemperer. expectations buoyd film directed stanley donen, whvose coic touch viden, amon others, damn yankees! , bedazzled charade. first five mtinu & tes, , seems expectaZtHiqons might met. nothing. supposed light comedy, plunges leaden, heavy hnded melodrama, nary cuckl had. relative newcomer suzy parker often pcrOiticiized performance, lack one, film, movie even grea cary grant frequently appears flat wooden, attacking parker seem_s unfair. even bright light audrey hepburn doris day could changed fortunes meandering, dreary wholly pointless script, drags lamely along drags vi + ewer ' interest patience it. the rest cast, especially ray walston, keep trying breath life proceedings, horrible script beyond resuscitation. desperate, inane effor drag hYalf hearted laugh numbed Ha (udience film ' final moments serves add insult injury. this film nothing major disappointment levels.",
#  "leveq high expectation sit wajch comedy cast headed cary grant, iayne mansfield, ray walston werner klemperer. expectaZtioqn_s buoyed film directed stanley donen, Uphose comic touch evNvent, among others, d_amn yankees! , bedazzled charade. first Give minutes, , seees expectations might met. notG7ng. supposed light comedy, plunges leadewn, heavy han8ed melodrama, nary chuckle had. Ureklative ndscomer suXy parker oftDn criticized performance, lack one, fi7lm, movie even great cary grant frequently appears flat wooden, attacking parker seems unfa3r. even bright light audrsy hepburn doris day could changed foet7nes meandering, drewry wholly pointless script, drags lamely along drags viewe4 ' iXneterest patience it. the rest cast, especially ray walston, ke1eo trying breath life proceedings, hou4ible scrippt beyond resuscitation. desperate, inane effort 7drag half hearted laugh numbed audience film ' final moments serves add insult injury. this film nothing major disappo@otbend levels."]

# %%
aug_train_sent = train_sentences.copy()
aug_train_label = train_labels.copy()

seconds = time.time()
for i in tqdm(range(len(train_sentences))):
    augmented_texts = aug.augment(train_sentences[i], n=4)
    for j in augmented_texts:
        aug_train_sent.append(j)
        aug_train_label.append(train_labels[i])
end = time.time()
print("Time taken for chracter level augmentation: {} s".format(end - seconds))
# Out:
# 100%|██████████| 3500/3500 [00:54<00:00, 64.75it/s]
# Time taken for chracter level augmentation: 54.072290658950806 s

# %%
char_aug_df = pd.DataFrame(
    {'cleaned': aug_train_sent,
     'label': aug_train_label
    })
char_aug_df.to_csv('char_aug_data.csv',index=False)

# %% [markdown]
# ## Non contextual word augmenter

# %% [markdown]
# Spelling

# %%
aug_spell = naw.SpellingAug()
augmented_texts = aug.augment(text, n=3)
print("Original:")
print(text)
print("Augmented Texts:")
print(augmented_texts)
# Out:
# Original:
# level high expectation sit watch comedy cast headed cary grant , jayne mansfield , ray walston werner klemperer. expectations buoyed film directed stanley donen , whose comic touch evident , among others , damn yankees ! , bedazzled charade. first five minutes , , seems expectations might met . nothing. supposed light comedy , plunges leaden , heavy handed melodrama , nary chuckle had.relative newcomer suzy parker often criticized performance , lack one , film , movie even great cary grant frequently appears flat wooden , attacking parker seems unfair. even bright light audrey hepburn doris day could changed fortunes meandering , dreary wholly pointless script , drags lamely along drags viewer ' interest patience it.the rest cast , especially ray walston , keep trying breath life proceedings , horrible script beyond resuscitation. desperate , inane effort drag half hearted laugh numbed audience film ' final moments serves add insult injury.this film nothing major disappointment levels .
# Augmented Texts:
# ["level high expectation sit watch comedy cast headed cary grant, jayne mansfield, ray walston qwerner klemperer. expectations buoyed film di9rec^ted 2stanl)ey doKnen, Ehose comic toHch evident, am0ng others, damn yankees! , bedazzled c!harJade. first five minutes, , seems expeoctat2ionms might met. nothing. supposed light comedy, plunges leaden, heavy handed melodrama, nary chuckle had. relative newcomer suzy parker often criticized performance, lack one, film, movie even great cary grant frequently appears flat wooden, attacking parker seems unfair. even bright light audrey hepburn doris day could changed fortunes meandering, dreary wholly pointless script, druags lamely along drags viewer ' interest patience it. the rest cast, especially ray walston, keep trying breath life proceedings, horrible scGipt beyond reC tscitatioB. deAperat #, inaje effort drag half hearted laugh numbed auYdi1ence film ' final moKrnts seTves add insult injury. this fi$lm nothing major diZxlpoinYment lhevels.", "level hihg expectation sit watch comedy cast headed cary gratn, jayne mansfield, ray walston werner klemperer. expectations buoyed film directed stanley uonen, whose comci tLuch evident, among cthers, dams yankees! , bedazzled hcaarde. first five mlutnFF, , ceems expectations might met. nothing. s6lposed light comedy, $ lungKs leaden, heavy handed melodrama, _ary chuckle had. relative newcomer sJzy parker often criticized performance, lack one, film, movie even great cary grant fdequRnt; y appears flat wooden, attacking parker seems unfair. even bright l @ ght audrey hepburn roris day could changed fortunes meandering, dreary Dholly pointless script, drags lamely along drags viewer ' interest pstiencw it. the rest cats, especially ray walston, keep tryign breath life proceedings, horrible script beyond resuscitation. desperate, ina + e fefort drag half hearted laugh numbed audience film ' final ommetns serves add Lnsult injruy. this film nothing major disapPlixtme7t levels.", "level high expectation sit watch comedy ca8t headed cary grant, jayne mansfield, kay walston werner klemperer. expectations buoyed film directed stanley donen, whose comic touch evident, among others, damn yankees! , bedazzled charade. first five minutes, , seems expectations might met. nothing. soppused light comedy, plunges leaden, heavy handed melodrama, nary chuckle had. relative newcomer suzy parker uften criticized performance, lack one, film, movie even great cary grant frequently appears flat wooden, attacking parker seems unfair. even bright light audrey hep6orn doris day could changed fortunes meandering, dreary wholly pointless script, drags lamely along drags viewer ' interest patience it. the rest cast, especially ray walston, keep trying breath life pr0ceedin98, horrible script beyond resuscitation. desperate, inane effort drag half heakted laugh numbed audience film ' final moments serves add insult injury. this film nothing major disappointment levels."]

# %% [markdown]
# ### TFIDF augmenter

# %%
import sklearn.datasets
import re

import nlpaug.augmenter.word as naw
import nlpaug.model.word_stats as nmw

def _tokenizer(text, token_pattern=r"(?u)\b\w\w+\b"):
    token_pattern = re.compile(token_pattern)
    return token_pattern.findall(text)

# Load sample data
# train_data = sklearn.datasets.fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'))
# train_x = train_data.data
train_x = train_sentences.copy()


# Tokenize input
train_x_tokens = [_tokenizer(x) for x in train_x]

# # Train TF-IDF model
tfidf_model = nmw.TfIdf()
tfidf_model.train(train_x_tokens)
tfidf_model.save('/content/drive/MyDrive/Y3S1/CZ4042 Neural network and deep learning/Group project /')

# # Load TF-IDF augmenter
aug = naw.TfIdfAug(model_path='/content/drive/MyDrive/Y3S1/CZ4042 Neural network and deep learning/Group project /', tokenizer=_tokenizer)

texts = [
    'The quick brown fox jumps over the lazy dog',
    'asdasd test apple dog asd asd'
]

for text in texts:
    augmented_text = aug.augment(text)
    
    print('-'*20)
    print('Original Input:{}'.format(text))
    print('Agumented Output:{}'.format(augmented_text))
# Out:
# --------------------
# Original Input:The quick brown fox jumps over the lazy dog
# Agumented Output:The quick brown fox jumps coconut the our dog
# --------------------
# Original Input:asdasd test apple dog asd asd
# Agumented Output:asdasd test apple triggered asd asd

# %%
aug_tfidf_ins = naw.TfIdfAug(
    model_path='/content/tfidfaug_w2idf.txt',
    action="insert")
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# asdasd test apple dog asd asd
# Augmented Text:
# asdasd test apple avjo asd asd

# %% [markdown]
# tfidf --> substitute

# %%
aug_tfidf_sub = naw.TfIdfAug(
    model_path='/content/tfidfaug_w2idf.txt',
    action="substitute")
augmented_text = aug.augment(text,n=5)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# asdasd test apple dog asd asd
# Augmented Text:
# ['asdasd test apple grapple asd asd', 'asdasd brainwashing apple dog asd asd', 'asdasd melts apple dog asd asd', 'asdasd test apple travesty asd asd', 'asdasd test pitiable dog asd asd']

# %%
aug_word = naf.Sometimes([
    aug_spell,
    aug_tfidf_ins,
    aug_tfidf_sub,
])

augmented_text = aug_word.augment(text, n=4)
augmented_text
# Out:
# ['Blasé asdasd test apple dog asd asd',
#  'asdasd mecca apple dog asd asd',
#  'asdasd test apple denmark dog asd asd',
#  'asdasd test apple dadg asd asd']

# %%
aug_train_sent = train_sentences.copy()
aug_train_label = train_labels.copy()

start = time.time()
for i in tqdm(range(len(train_sentences))):
    augmented_texts = aug_word.augment(train_sentences[i], n=4)
    while len(augmented_texts)<4:
        augmented_texts += augmented_texts
    augmented_texts = augmented_texts[:4]

    for j in augmented_texts:
        aug_train_sent.append(j)
        aug_train_label.append(train_labels[i])
end = time.time()
print("Time taken for word level non-contextual augmentation: {} s".format(end - start))
# Out:
# 100%|██████████| 3500/3500 [04:40<00:00, 12.48it/s]
# Time taken for word level non-contextual augmentation: 280.37355756759644 s

# %%
non_cont_word_aug_df = pd.DataFrame(
    {'cleaned': aug_train_sent,
     'label': aug_train_label
    })
non_cont_word_aug_df.to_csv('non_cont_word_aug_df.csv',index=False)

# %% [markdown]
# synonym and antonym

# %%
aug_syn_sub = naw.SynonymAug(aug_src='wordnet')
augmented_text = aug_syn_sub.augment(_text)
print("Original:")
print(_text)
print("Augmented Text:")
print(augmented_text)

# %%
aug_ant = naw.AntonymAug()
_text = train_sentences[0]
augmented_text = aug_ant.augment(_text)
print("Original:")
print(_text)
print("Augmented Text:")
print(augmented_text)

# %%
aug_train_sent = train_sentences.copy()
aug_train_label = train_labels.copy()

#2 times synonym substitution
for i in tqdm(range(len(train_sentences))):
    augmented_texts_syn = aug_syn_sub.augment(train_sentences[i], n=2)
    for j in augmented_texts_syn:
        aug_train_sent.append(j)
        aug_train_label.append(train_labels[i])

#2 times antonym substitution,  and change label to opposite label
for i in tqdm(range(len(train_sentences))):
    augmented_texts_ant = aug_ant.augment(train_sentences[i], n=2)
    for j in augmented_texts_ant:
        aug_train_sent.append(j)
        if train_labels[i]:
            aug_train_label.append(0)
        else:
            aug_train_label.append(1)
